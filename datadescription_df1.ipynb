# %% [markdown]
# ## Dataset Description

# %% [markdown]
# In data mining and machine learning, pandas are used as streamlined tools to manipulate, explore, and analyse the data. Meanwhile, Numpy is helpful in calculation section of the data mining.<br><br>
# By using these libraries, we can identify the pattern in the data and understand the data better.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Firstly, we need to mount Google Drive in this notebook in order to allow the link of datasets stored in Google Drive imported into this notebook.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# In our project, we are loading CSV type of file into this noteboook. Hence, pd.read_csv() is used to import and load CSV file into this notebook.

# %%
dataset = pd.read_csv('/content/drive/MyDrive/TDM_project/Walmart.csv')

# %% [markdown]
# This data contains different attribute of information on customer details and their purchasing behaviors. The Walmart's Customer Purchasing Behavior data includes columns for user ID, age, annual income, purchase amount, loyalty score, region, and purchase frequency. These data are created with the purpose of analyzing customer segmentation and loyalty trends, which then can be used for different kinds of machine learning and data analysis works that are related to customer behavior and market research.
# <br><br>
# The detailed data dictionary is given below:
# <br><br>
# **Data Dictionary**
# <br>user_id: Unique ID of each customer
# <br>age: The age of each customer
# <br>annual_income: Customer's annual income in USD
# <br>purchase_amount: Total amount of purchases made by the customer in USD
# <br>loyalty_score: A value of 0-100 for
#  Customer's loyalty score
# <br>region: Region where each respective customer lives
# <br>purchase_frequency: Number of time of customer purchases per year

# %% [markdown]
# By having the data dictionary of the Walmart's Customer Purchasing Behavior, readers can gain better understanding of the dataset before starting the data mining task.
